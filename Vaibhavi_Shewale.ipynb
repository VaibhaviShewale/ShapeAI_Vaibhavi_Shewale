# %%
from keras.datasets import mnist

data = mnist.load_data()

# %%
((X_train, y_train), (X_test, y_test)) = data

# %%
X_train = X_train.reshape((X_train.shape[0],28*28)).astype('float32')
X_test = X_test.reshape((X_test.shape[0],28*28)).astype('float32')

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
from keras.utils import np_utils
 
print(y_test.shape)
 
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
 
num_classes = y_test.shape[1]
print(y_test.shape)
# Out:
# (10000,)
# (10000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential ()
model.add(Dense(32, input_dim = 28*28, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.7437 - accuracy: 0.7969
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1979 - accuracy: 0.9420
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1464 - accuracy: 0.9564
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1230 - accuracy: 0.9637
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1035 - accuracy: 0.9697
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0931 - accuracy: 0.9724
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0839 - accuracy: 0.9741
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0706 - accuracy: 0.9784
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0671 - accuracy: 0.9800
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0578 - accuracy: 0.9828

# %%
scores = model.evaluate(X_test, y_test)
print (scores)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1120 - accuracy: 0.9662
# [0.11199919134378433, 0.9661999940872192]
